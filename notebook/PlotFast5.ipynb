# %%
import numpy as np
import h5py
# %matplotlib inline
import seaborn as sns
# %load_ext autoreload
# %autoreload 1
import matplotlib.pyplot as plt
# %aimport mincall.tools.plot_fast5
tt = mincall.tools.plot_fast5
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_prefix = "/home/lpp/Downloads/minion/pass/"
fig, axes = plt.subplots(4, 2, sharey=True)
fig.set_size_inches(16, 20)
for ax, fname in zip(axes.ravel(), os.listdir(data_prefix)):
    tt.fast5_fix(os.path.join(data_prefix, fname), ax)
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
